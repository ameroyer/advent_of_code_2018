# %% [markdown]
# ## ❄️ [Day 7](https://adventofcode.com/2018/day/7)

# %%
import collections

def build_dependencies(inputs):
  """Build the graph from the given inputs, getting forward and backward dependencies"""
  dependencies = collections.defaultdict(lambda: [])
  forward = collections.defaultdict(lambda: [])
  for ante, poste in inputs:
    forward[ante].append(poste)
    dependencies[poste].append(ante)
  forward = {k: sorted(v) for k, v in forward.items()}
  leaves = set(dependencies.keys())
  parents = set(forward.keys())
  roots = parents - leaves
  return sorted(list(roots), reverse=True), dependencies, forward

def is_valid(dependencies, path):
  """Check if all dependecies in the list are met from the current path"""
  for k in dependencies:
    if not k in path:
      return False
  return True

def iter_path(path, available, forward, dependencies):  
  """One step iteration to build the path given the current available nodes and dependencies"""
  current_node = available.pop()
  path += current_node
  if current_node in forward:
    for successor in forward[current_node]:
      if is_valid(dependencies[successor], path):
        available.append(successor)
    available = sorted(available, reverse=True)
  return path, available
    
def find_path(inputs):
  """Build the path with 1 worker"""
  path =''
  roots, dependencies, forward = build_dependencies(inputs)
  available = roots          
  while len(available):
    path, available = iter_path(path, available, forward, dependencies)    
  return path    


def get_time(letter, short=False):
  """Get the time needed to execute the task assigned to the given letter. 
  optional short option remove 60s for lighter display"""
  return ord(letter) - 4 - int(short) * 60

def iter_path_parallel(path, available, workers, forward, dependencies, short=False): 
  """One step iteration to build the timedpath given the current available nodes and dependencies"""
  for worker in workers:    
    # If task is in process, remove one unit of time
    if worker['task'] is not None:
      worker['remaining_time'] -= 1  
      # if finished task, reset
      if worker['remaining_time'] == 0: # finish a task
        path += worker['task']
        if worker['task'] in forward:
          for successor in forward[worker['task']]:
            if is_valid(dependencies[successor], path):
              available.append(successor)
          available = sorted(available, reverse=True)
        worker['task'] = None         
    # If worker was or is now free, assign a new task
    if worker['task'] is None:
      if len(available):
        current_node = available.pop()
        worker['task'] = current_node
        worker['remaining_time'] = get_time(current_node, short=short)        
  # Return
  return path, available

def all_workers_finished(workers):
  """Test if all workers are currently idle"""
  for w in workers:
    if w['task'] is not None or w['remaining_time'] > 0:
      return False
  return True

def find_timed_path(inputs, num_workers=5):
  """Build the timed path with n workers"""
  roots, dependencies, forward = build_dependencies(inputs)
  available_workers = [{'task': None, 'remaining_time': 0} for _ in range(num_workers)]
  path = ''
  available = roots
  num_iters = 0
  while len(path) == 0 or not all_workers_finished(available_workers):
    path, available = iter_path_parallel(path, available, available_workers, 
                                         forward, dependencies, short=False)
    num_iters += 1
  return num_iters - 1, path

# %%
with open("day7.txt", 'r') as f:
  inputs = [[letter for letter in x if letter.isalpha() and letter == letter.upper()][1:] 
            for x in f.read().splitlines()]
  
  print('Correct order:', find_path(inputs))
print('Time to complete with 5 workers:', find_timed_path(inputs, num_workers=5))
# Out:
# Correct order: SCLPAMQVUWNHODRTGYKBJEFXZI
# Time to complete with 5 workers: (1234, 'SCLPAMQVWYNUHODTRGKBJEFXZI')

# %%
#@title Visualize the graph
import networkx as nx
from matplotlib import pyplot as plt

def hierarchy_pos(G, root, base_width=0.2, width=1.0, vert_gap=0.8, vert_loc=0, xcenter=0.5, pos=None, parent=None):
  """Source: https://stackoverflow.com/questions/29586520/can-one-get-hierarchical-graphs-from-networkx-with-python-3"""
  if pos == None:
      pos = {root:(xcenter,vert_loc)}
  else:
      pos[root] = (xcenter, vert_loc)
  neighbors = list(G.neighbors(root))
  if len(neighbors)!=0:
      dx = width / len(neighbors)
      nextx = xcenter - width/2 - dx/2
      for neighbor in neighbors:
          nextx += dx
          pos = hierarchy_pos(G, neighbor, width=dx + base_width, vert_gap=vert_gap, 
                              vert_loc=vert_loc-vert_gap, xcenter=nextx, pos=pos, 
                              parent=root)
  return pos
  
  
def visualize(inputs, path):
  roots, _, _ = build_dependencies(inputs)
  plt.figure(figsize=(12, 12))
  G = nx.DiGraph()  
  G.add_edges_from(inputs)
  pos = hierarchy_pos(G, roots[0])
  nx.draw(G, pos=pos, arrows=True, with_labels=True, node_size=500, node_color='xkcd:azure',
          font_color='white', font_weight='bold')
  # not accurate because the path does not necessarily follow consecutive node, but works in practice
  nx.draw_networkx_edges(G, pos=pos, edgelist=[[e, path[i + 1]] for i, e in enumerate(path[:-1])], edge_color='xkcd:orange', width=2)
  plt.show()
  
visualize(inputs, 'SCLPAMQVUWNHODRTGYKBJEFXZI')

# %%
#@title Visualize the path for timed tasks (with - 60s times)
# Note that this is not exactly equivalent to the version with 60+ seconds 
# But this is much simpler for visualization purposes

def print_workers(second, workers, path):
  print('%06d  ' % second, '  '.join(
      '    %s    ' % (w['task'] if w['task'] is not None else '.')
      for w in workers), ' ', path)
  
def visualize(inputs, num_workers=5, short=True):
  roots, dependencies, forward = build_dependencies(inputs)
  available_workers = [{'task': None, 'remaining_time': 0} for _ in range(num_workers)]
  path = ''
  available = roots
  num_iters = 0
  print('Second -', ' - '.join('Worker %03d' % (k + 1) for k in range(num_workers)), '- Path')
  while len(path) == 0 or not all_workers_finished(available_workers):
    path, available = iter_path_parallel(path, available, available_workers, 
                                         forward, dependencies, short=short)
    print_workers(num_iters, available_workers, path)
    num_iters += 1
    
visualize(inputs, num_workers=5)
# Out:
# Second - Worker 001 - Worker 002 - Worker 003 - Worker 004 - Worker 005 - Path
# 000000       S          .          .          .          .
# 000001       S          .          .          .          .
# 000002       S          .          .          .          .
# 000003       S          .          .          .          .
# 000004       S          .          .          .          .
# 000005       S          .          .          .          .
# 000006       S          .          .          .          .
# 000007       S          .          .          .          .
# 000008       S          .          .          .          .
# 000009       S          .          .          .          .
# 000010       S          .          .          .          .
# 000011       S          .          .          .          .
# 000012       S          .          .          .          .
# 000013       S          .          .          .          .
# 000014       S          .          .          .          .
# 000015       S          .          .          .          .
# 000016       S          .          .          .          .
# 000017       S          .          .          .          .
# 000018       S          .          .          .          .
# 000019       C          .          .          .          .       S
# 000020       C          .          .          .          .       S
# 000021       C          .          .          .          .       S
# 000022       L          P          .          .          .       SC
# 000023       L          P          .          .          .       SC
# 000024       L          P          .          .          .       SC
# 000025       L          P          .          .          .       SC
# 000026       L          P          .          .          .       SC
# 000027       L          P          .          .          .       SC
# 000028       L          P          .          .          .       SC
# 000029       L          P          .          .          .       SC
# 000030       L          P          .          .          .       SC
# 000031       L          P          .          .          .       SC
# 000032       L          P          .          .          .       SC
# 000033       L          P          .          .          .       SC
# 000034       V          P          W          .          .       SCL
# 000035       V          P          W          .          .       SCL
# 000036       V          P          W          .          .       SCL
# 000037       V          P          W          .          .       SCL
# 000038       V          A          W          M          Q       SCLP
# 000039       V          Y          W          M          Q       SCLPA
# 000040       V          Y          W          M          Q       SCLPA
# 000041       V          Y          W          M          Q       SCLPA
# 000042       V          Y          W          M          Q       SCLPA
# 000043       V          Y          W          M          Q       SCLPA
# 000044       V          Y          W          M          Q       SCLPA
# 000045       V          Y          W          M          Q       SCLPA
# 000046       V          Y          W          M          Q       SCLPA
# 000047       V          Y          W          M          Q       SCLPA
# 000048       V          Y          W          M          Q       SCLPA
# 000049       V          Y          W          M          Q       SCLPA
# 000050       V          Y          W          M          Q       SCLPA
# 000051       V          Y          W          .          Q       SCLPAM
# 000052       V          Y          W          .          Q       SCLPAM
# 000053       V          Y          W          .          Q       SCLPAM
# 000054       V          Y          W          .          Q       SCLPAM
# 000055       V          Y          W          .          .       SCLPAMQ
# 000056       U          Y          W          .          .       SCLPAMQV
# 000057       U          Y          N          .          .       SCLPAMQVW
# 000058       U          Y          N          .          .       SCLPAMQVW
# 000059       U          Y          N          .          .       SCLPAMQVW
# 000060       U          Y          N          .          .       SCLPAMQVW
# 000061       U          Y          N          .          .       SCLPAMQVW
# 000062       U          Y          N          .          .       SCLPAMQVW
# 000063       U          Y          N          .          .       SCLPAMQVW
# 000064       U          .          N          .          .       SCLPAMQVWY
# 000065       U          .          N          .          .       SCLPAMQVWY
# 000066       U          .          N          .          .       SCLPAMQVWY
# 000067       U          .          N          .          .       SCLPAMQVWY
# 000068       U          .          N          .          .       SCLPAMQVWY
# 000069       U          .          N          .          .       SCLPAMQVWY
# 000070       U          .          N          .          .       SCLPAMQVWY
# 000071       U          .          H          .          .       SCLPAMQVWYN
# 000072       U          .          H          .          .       SCLPAMQVWYN
# 000073       U          .          H          .          .       SCLPAMQVWYN
# 000074       U          .          H          .          .       SCLPAMQVWYN
# 000075       U          .          H          .          .       SCLPAMQVWYN
# 000076       U          .          H          .          .       SCLPAMQVWYN
# 000077       .          .          H          .          .       SCLPAMQVWYNU
# 000078       .          .          H          .          .       SCLPAMQVWYNU
# 000079       .          .          O          .          .       SCLPAMQVWYNUH
# 000080       .          .          O          .          .       SCLPAMQVWYNUH
# 000081       .          .          O          .          .       SCLPAMQVWYNUH
# 000082       .          .          O          .          .       SCLPAMQVWYNUH
# 000083       .          .          O          .          .       SCLPAMQVWYNUH
# 000084       .          .          O          .          .       SCLPAMQVWYNUH
# 000085       .          .          O          .          .       SCLPAMQVWYNUH
# 000086       .          .          O          .          .       SCLPAMQVWYNUH
# 000087       .          .          O          .          .       SCLPAMQVWYNUH
# 000088       .          .          O          .          .       SCLPAMQVWYNUH
# 000089       .          .          O          .          .       SCLPAMQVWYNUH
# 000090       .          .          O          .          .       SCLPAMQVWYNUH
# 000091       .          .          O          .          .       SCLPAMQVWYNUH
# 000092       .          .          O          .          .       SCLPAMQVWYNUH
# 000093       .          .          O          .          .       SCLPAMQVWYNUH
# 000094       .          .          D          T          .       SCLPAMQVWYNUHO
# 000095       .          .          D          T          .       SCLPAMQVWYNUHO
# 000096       .          .          D          T          .       SCLPAMQVWYNUHO
# 000097       .          .          D          T          .       SCLPAMQVWYNUHO
# 000098       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000099       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000100       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000101       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000102       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000103       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000104       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000105       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000106       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000107       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000108       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000109       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000110       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000111       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000112       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000113       .          .          R          T          .       SCLPAMQVWYNUHOD
# 000114       .          .          R          G          .       SCLPAMQVWYNUHODT
# 000115       .          .          R          G          .       SCLPAMQVWYNUHODT
# 000116       .          .          .          G          .       SCLPAMQVWYNUHODTR
# 000117       .          .          .          G          .       SCLPAMQVWYNUHODTR
# 000118       .          .          .          G          .       SCLPAMQVWYNUHODTR
# 000119       .          .          .          G          .       SCLPAMQVWYNUHODTR
# 000120       .          .          .          G          .       SCLPAMQVWYNUHODTR
# 000121       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000122       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000123       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000124       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000125       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000126       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000127       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000128       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000129       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000130       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000131       .          .          .          K          .       SCLPAMQVWYNUHODTRG
# 000132       .          .          .          B          .       SCLPAMQVWYNUHODTRGK
# 000133       .          .          .          B          .       SCLPAMQVWYNUHODTRGK
# 000134       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000135       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000136       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000137       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000138       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000139       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000140       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000141       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000142       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000143       .          .          .          J          .       SCLPAMQVWYNUHODTRGKB
# 000144       .          .          .          E          .       SCLPAMQVWYNUHODTRGKBJ
# 000145       .          .          .          E          .       SCLPAMQVWYNUHODTRGKBJ
# 000146       .          .          .          E          .       SCLPAMQVWYNUHODTRGKBJ
# 000147       .          .          .          E          .       SCLPAMQVWYNUHODTRGKBJ
# 000148       .          .          .          E          .       SCLPAMQVWYNUHODTRGKBJ
# 000149       .          .          .          F          .       SCLPAMQVWYNUHODTRGKBJE
# 000150       .          .          .          F          .       SCLPAMQVWYNUHODTRGKBJE
# 000151       .          .          .          F          .       SCLPAMQVWYNUHODTRGKBJE
# 000152       .          .          .          F          .       SCLPAMQVWYNUHODTRGKBJE
# 000153       .          .          .          F          .       SCLPAMQVWYNUHODTRGKBJE
# 000154       .          .          .          F          .       SCLPAMQVWYNUHODTRGKBJE
# 000155       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000156       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000157       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000158       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000159       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000160       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000161       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000162       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000163       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000164       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000165       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000166       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000167       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000168       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000169       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000170       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000171       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000172       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000173       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000174       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000175       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000176       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000177       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000178       .          .          .          X          .       SCLPAMQVWYNUHODTRGKBJEF
# 000179       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000180       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000181       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000182       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000183       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000184       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000185       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000186       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000187       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000188       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000189       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000190       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000191       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000192       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000193       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000194       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000195       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000196       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000197       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000198       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000199       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000200       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000201       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000202       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000203       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000204       .          .          .          Z          .       SCLPAMQVWYNUHODTRGKBJEFX
# 000205       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000206       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000207       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000208       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000209       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000210       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000211       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000212       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000213       .          .          .          I          .       SCLPAMQVWYNUHODTRGKBJEFXZ
# 000214       .          .          .          .          .       SCLPAMQVWYNUHODTRGKBJEFXZI
